# %% [markdown]
# # Análise do Data Warehouse - (Cursos Superior, Cor/Raça, Brasil)
#
# Análise dos dados disponibilizados no Data Warehouse
#
#
#
# **Instalando o Cassandra no Jupyter**
#
# `docker-compose exec jupyter pip install cassandra-driver`

# %% [markdown]
# ## Imports

# %%
#Imports
from time import sleep

# %%
#Imports Cassandra
from cassandra.auth import PlainTextAuthProvider
from cassandra.cluster import Cluster

# %%
#Imports Pandas
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
def pandas_factory(colnames, rows):
    return pd.DataFrame(rows, columns=colnames)

# %% [markdown]
# ## Conexão ao banco de Dados Cassandra

# %%
#Conectando a seção
ap = PlainTextAuthProvider(username='cassandra', password='cassandra')
cluster = Cluster(['cassandra'], protocol_version=4, auth_provider=ap)
session = cluster.connect('alunos')
session.default_timeout = 60
session.row_factory = pandas_factory
sleep(2)

# %% [markdown]
# ## Consulta

# %%
table = 'fato_aluno_cor'
field = 'cor_raca'
curse_types = ['Bacharelado','Licenciatura','Tecnologia']
filters = {    
    'categoria_situacao': ['Evadidos','Concluintes'],
    'unidade_ensino': '',
    'instituicao': 'IFPB',
}

# %%
s = []
for k, v in filters.items():
    if v :
        if type(v) is str:
            s.append("({} = '{}')".format(k,v))
        elif type(v) is list:
            s.append("({} IN ({}))".format(
                k,
                ','.join(map(str,["'{}'".format(i) for i in v]))))
filter_sql = " AND ".join(map(str,s))

# %%
# Análise de Sexo
sql = "SELECT categoria_situacao, {0}, tipo_curso, instituicao, unidade_ensino, sum(quant_grupo) AS quant_grupo" \
" FROM {1} " \
" WHERE {2} " \
" GROUP BY categoria_situacao, {0}, tipo_curso, instituicao " \
" ALLOW FILTERING;".format(
    field, 
    table,
    filter_sql)
rslt = session.execute(sql, timeout=None)
df = rslt._current_rows
df
# Out:
#    categoria_situacao cor_raca                       tipo_curso instituicao  \
# 0         Concluintes  Amarela                      Bacharelado        IFPB
# 1         Concluintes  Amarela                     Licenciatura        IFPB
# 2         Concluintes  Amarela  Qualificação Profissional (FIC)        IFPB
# 3         Concluintes  Amarela                       Tecnologia        IFPB
# 4         Concluintes  Amarela                          Técnico        IFPB
# ..                ...      ...                              ...         ...
# 68           Evadidos    Preta      Especialização (Lato Sensu)        IFPB
# 69           Evadidos    Preta                     Licenciatura        IFPB
# 70           Evadidos    Preta  Qualificação Profissional (FIC)        IFPB
# 71           Evadidos    Preta                       Tecnologia        IFPB
# 72           Evadidos    Preta                          Técnico        IFPB
#
#                      unidade_ensino  quant_grupo
# 0                Campus João Pessoa            3
# 1                Campus João Pessoa            3
# 2    Campus Avançado Pedras de Fogo           15
# 3                   Campus Cabedelo           13
# 4   Campus Avançado Cabedelo Centro           44
# ..                              ...          ...
# 68               Campus João Pessoa            4
# 69                  Campus Cabedelo           68
# 70            Campus Avançado Areia           42
# 71                  Campus Cabedelo          119
# 72            Campus Avançado Areia          335
#
# [73 rows x 6 columns]

# %% [markdown]
# ## Filtrando Tipo do Curso

# %%
if curse_types :
    df = df[df['tipo_curso'].isin(curse_types)]
    print('Fitrando pelos tipos de cursos:\n {}'.format(', '.join(map(str,curse_types))))
    
else:
    print('Todos os cursos')
df
# Out:
# Fitrando pelos tipos de cursos:
#  Bacharelado, Licenciatura, Tecnologia
#    categoria_situacao       cor_raca    tipo_curso instituicao  \
# 0         Concluintes        Amarela   Bacharelado        IFPB
# 1         Concluintes        Amarela  Licenciatura        IFPB
# 3         Concluintes        Amarela    Tecnologia        IFPB
# 5         Concluintes         Branca   Bacharelado        IFPB
# 7         Concluintes         Branca  Licenciatura        IFPB
# 10        Concluintes         Branca    Tecnologia        IFPB
# 13        Concluintes       Indígena    Tecnologia        IFPB
# 15        Concluintes  Não Declarada   Bacharelado        IFPB
# 17        Concluintes  Não Declarada  Licenciatura        IFPB
# 20        Concluintes  Não Declarada    Tecnologia        IFPB
# 22        Concluintes          Parda   Bacharelado        IFPB
# 24        Concluintes          Parda  Licenciatura        IFPB
# 27        Concluintes          Parda    Tecnologia        IFPB
# 29        Concluintes          Preta   Bacharelado        IFPB
# 31        Concluintes          Preta  Licenciatura        IFPB
# 33        Concluintes          Preta    Tecnologia        IFPB
# 35           Evadidos        Amarela   Bacharelado        IFPB
# 37           Evadidos        Amarela  Licenciatura        IFPB
# 39           Evadidos        Amarela    Tecnologia        IFPB
# 41           Evadidos         Branca   Bacharelado        IFPB
# 43           Evadidos         Branca  Licenciatura        IFPB
# 47           Evadidos         Branca    Tecnologia        IFPB
# 50           Evadidos       Indígena    Tecnologia        IFPB
# 52           Evadidos  Não Declarada   Bacharelado        IFPB
# 54           Evadidos  Não Declarada  Licenciatura        IFPB
# 57           Evadidos  Não Declarada    Tecnologia        IFPB
# 59           Evadidos          Parda   Bacharelado        IFPB
# 61           Evadidos          Parda  Licenciatura        IFPB
# 65           Evadidos          Parda    Tecnologia        IFPB
# 67           Evadidos          Preta   Bacharelado        IFPB
# 69           Evadidos          Preta  Licenciatura        IFPB
# 71           Evadidos          Preta    Tecnologia        IFPB
#
#            unidade_ensino  quant_grupo
# 0      Campus João Pessoa            3
# 1      Campus João Pessoa            3
# 3         Campus Cabedelo           13
# 5       Campus Cajazeiras           85
# 7       Campus Cajazeiras           73
# 10        Campus Cabedelo          274
# 13        Campus Monteiro            1
# 15      Campus Cajazeiras           44
# 17      Campus Cajazeiras           58
# 20        Campus Cabedelo          200
# 22      Campus Cajazeiras           87
# 24        Campus Cabedelo           88
# 27        Campus Cabedelo          363
# 29     Campus João Pessoa           13
# 31      Campus Cajazeiras           16
# 33        Campus Cabedelo           55
# 35  Campus Campina Grande            4
# 37      Campus Cajazeiras            9
# 39        Campus Cabedelo           25
# 41      Campus Cajazeiras          128
# 43        Campus Cabedelo          290
# 47        Campus Cabedelo          588
# 50        Campus Cabedelo            7
# 52      Campus Cajazeiras           29
# 54        Campus Cabedelo          118
# 57        Campus Cabedelo          254
# 59      Campus Cajazeiras          142
# 61        Campus Cabedelo          456
# 65        Campus Cabedelo          875
# 67      Campus Cajazeiras           26
# 69        Campus Cabedelo           68
# 71        Campus Cabedelo          119

# %% [markdown]
# ## Agrupando

# %%
df = df.groupby(['categoria_situacao',field]).sum('quant_grupo').reset_index()

# %%
x = df.pivot_table('quant_grupo',[field],'categoria_situacao')
#x = df.pivot_table('quant_grupo',['categoria_situacao'],field)
x.plot(kind ='bar', figsize=(20, 8), width = 0.7)
# Out:
# <AxesSubplot:xlabel='cor_raca'>

# %% [markdown]
# ## Total de Alunos

# %%
categorias = list(df['categoria_situacao'].unique())
total = df['quant_grupo'].sum()
x = df.pivot_table('quant_grupo',index=[field],columns='categoria_situacao').reset_index()
x['total'] = x[categorias].sum(axis=1)
for categoria in categorias:
    x[categoria + '_%'] = x[categoria] / x['total']
x['total_%'] = x['total'] / total
x.sort_values(by=['total_%'], ascending=False)
# Out:
# categoria_situacao       cor_raca  Concluintes  Evadidos  total  \
# 4                           Parda          538      1473   2011
# 1                          Branca          432      1006   1438
# 3                   Não Declarada          302       401    703
# 5                           Preta           84       213    297
# 0                         Amarela           19        38     57
# 2                        Indígena            1         7      8
#
# categoria_situacao  Concluintes_%  Evadidos_%   total_%
# 4                        0.267529    0.732471  0.445503
# 1                        0.300417    0.699583  0.318564
# 3                        0.429587    0.570413  0.155738
# 5                        0.282828    0.717172  0.065795
# 0                        0.333333    0.666667  0.012627
# 2                        0.125000    0.875000  0.001772

# %%
print("Total de alunos: {:,}".format(df['quant_grupo'].sum()).replace(',','.'))
# Out:
# Total de alunos: 4.514
