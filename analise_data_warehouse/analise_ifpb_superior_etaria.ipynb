# %% [markdown]
# # Análise do Data Warehouse
#
# Análise dos dados disponibilizados no Data Warehouse
#
#
#
# **Instalando o Cassandra no Jupyter**
#
# `docker-compose exec jupyter pip install cassandra-driver`

# %% [markdown]
# ## Imports

# %%
#Imports
from time import sleep

# %%
#Imports Cassandra
from cassandra.auth import PlainTextAuthProvider
from cassandra.cluster import Cluster

# %%
#Imports Pandas
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
def pandas_factory(colnames, rows):
    return pd.DataFrame(rows, columns=colnames)

# %% [markdown]
# ## Conexão ao banco de Dados Cassandra

# %%
#Conectando a seção
ap = PlainTextAuthProvider(username='cassandra', password='cassandra')
cluster = Cluster(['cassandra'], protocol_version=4, auth_provider=ap)
session = cluster.connect('alunos')
session.default_timeout = 60
session.row_factory = pandas_factory
sleep(2)

# %% [markdown]
# ## Consulta

# %% [markdown]
# ### Configurando a consulta
# Atribuindo valores para as consultas

# %%
table = 'fato_aluno_etaria'
field = 'faixa_etaria'
curse_types = ['Bacharelado','Licenciatura','Tecnologia']
filters = {    
    'categoria_situacao': ['Evadidos','Concluintes'],
    field: True,
    'tipo_curso': len(curse_types) > 0,
    'instituicao': 'IFPB',
    'unidade_ensino': '',
    'nome_curso': '',
    
}

# %% [markdown]
# ### Construindo a string para a consulta
# Criando fields e grupos para a consulta

# %%
s = []
gf = []
for k, v in filters.items():
    if v :
        if type(v) is str:
            s.append("({} = '{}')".format(k,v))            
        elif type(v) is list:
            s.append("({} IN ({}))".format(
                k,','.join(map(str,["'{}'".format(i) for i in v]))))
        if (type(v) is bool and v) or (not type(v) is bool):
            gf.append(k)
filter_sql = " AND ".join(map(str,s))
fields = ", ".join(map(str,gf))

# %% [markdown]
# ### Execultado a consulta

# %%
#Execultado Consulta
sql = "SELECT {0}, sum(quant_grupo) AS quant_grupo" \
" FROM {1} " \
" WHERE {2} " \
" GROUP BY {0}" \
" ALLOW FILTERING;".format(
    fields,
    table,
    filter_sql)
rslt = session.execute(sql, timeout=None)
original_df = rslt._current_rows
original_df
# Out:
#     categoria_situacao      faixa_etaria                       tipo_curso  \
# 0          Concluintes      15 a 19 anos  Qualificação Profissional (FIC)
# 1          Concluintes      15 a 19 anos                       Tecnologia
# 2          Concluintes      15 a 19 anos                          Técnico
# 3          Concluintes      20 a 24 anos                      Bacharelado
# 4          Concluintes      20 a 24 anos      Especialização (Lato Sensu)
# ..                 ...               ...                              ...
# 123           Evadidos  Maior de 60 anos                       Tecnologia
# 124           Evadidos  Maior de 60 anos                          Técnico
# 125           Evadidos  Menor de 14 anos  Qualificação Profissional (FIC)
# 126           Evadidos  Menor de 14 anos                       Tecnologia
# 127           Evadidos  Menor de 14 anos                          Técnico
#
#     instituicao  quant_grupo
# 0          IFPB          381
# 1          IFPB            1
# 2          IFPB         1548
# 3          IFPB           81
# 4          IFPB            3
# ..          ...          ...
# 123        IFPB            6
# 124        IFPB            8
# 125        IFPB           12
# 126        IFPB            2
# 127        IFPB            7
#
# [128 rows x 5 columns]

# %% [markdown]
# ## Análise

# %%
s = original_df.shape
print("Número de registros {:,} e número de colunas {:,}.".format(s[0], s[1]).replace(',','.'))
# Out:
# Número de registros 128 e número de colunas 5.

# %% [markdown]
# ## Filtrando Tipo do Curso

# %%
if curse_types :
    original_df = original_df[original_df['tipo_curso'].isin(curse_types)]
    print('Fitrando pelos tipos de cursos:\n {}'.format(', '.join(map(str,curse_types))))
    
else:
    print('Todos os cursos')
original_df
# Out:
# Fitrando pelos tipos de cursos:
#  Bacharelado, Licenciatura, Tecnologia
#     categoria_situacao      faixa_etaria    tipo_curso instituicao  \
# 1          Concluintes      15 a 19 anos    Tecnologia        IFPB
# 3          Concluintes      20 a 24 anos   Bacharelado        IFPB
# 5          Concluintes      20 a 24 anos  Licenciatura        IFPB
# 8          Concluintes      20 a 24 anos    Tecnologia        IFPB
# 10         Concluintes      25 a 29 anos   Bacharelado        IFPB
# 12         Concluintes      25 a 29 anos  Licenciatura        IFPB
# 15         Concluintes      25 a 29 anos    Tecnologia        IFPB
# 17         Concluintes      30 a 34 anos   Bacharelado        IFPB
# 19         Concluintes      30 a 34 anos  Licenciatura        IFPB
# 22         Concluintes      30 a 34 anos    Tecnologia        IFPB
# 24         Concluintes      35 a 39 anos   Bacharelado        IFPB
# 26         Concluintes      35 a 39 anos  Licenciatura        IFPB
# 29         Concluintes      35 a 39 anos    Tecnologia        IFPB
# 31         Concluintes      40 a 44 anos   Bacharelado        IFPB
# 33         Concluintes      40 a 44 anos  Licenciatura        IFPB
# 36         Concluintes      40 a 44 anos    Tecnologia        IFPB
# 38         Concluintes      45 a 49 anos   Bacharelado        IFPB
# 40         Concluintes      45 a 49 anos  Licenciatura        IFPB
# 43         Concluintes      45 a 49 anos    Tecnologia        IFPB
# 45         Concluintes      50 a 54 anos   Bacharelado        IFPB
# 47         Concluintes      50 a 54 anos  Licenciatura        IFPB
# 49         Concluintes      50 a 54 anos    Tecnologia        IFPB
# 51         Concluintes      55 a 59 anos   Bacharelado        IFPB
# 53         Concluintes      55 a 59 anos  Licenciatura        IFPB
# 55         Concluintes      55 a 59 anos    Tecnologia        IFPB
# 57         Concluintes  Maior de 60 anos  Licenciatura        IFPB
# 59         Concluintes  Maior de 60 anos    Tecnologia        IFPB
# 63            Evadidos      15 a 19 anos   Bacharelado        IFPB
# 64            Evadidos      15 a 19 anos  Licenciatura        IFPB
# 66            Evadidos      15 a 19 anos    Tecnologia        IFPB
# 68            Evadidos      20 a 24 anos   Bacharelado        IFPB
# 70            Evadidos      20 a 24 anos  Licenciatura        IFPB
# 74            Evadidos      20 a 24 anos    Tecnologia        IFPB
# 76            Evadidos      25 a 29 anos   Bacharelado        IFPB
# 78            Evadidos      25 a 29 anos  Licenciatura        IFPB
# 80            Evadidos      25 a 29 anos    Tecnologia        IFPB
# 82            Evadidos      30 a 34 anos   Bacharelado        IFPB
# 84            Evadidos      30 a 34 anos  Licenciatura        IFPB
# 87            Evadidos      30 a 34 anos    Tecnologia        IFPB
# 89            Evadidos      35 a 39 anos   Bacharelado        IFPB
# 91            Evadidos      35 a 39 anos  Licenciatura        IFPB
# 93            Evadidos      35 a 39 anos    Tecnologia        IFPB
# 95            Evadidos      40 a 44 anos   Bacharelado        IFPB
# 97            Evadidos      40 a 44 anos  Licenciatura        IFPB
# 100           Evadidos      40 a 44 anos    Tecnologia        IFPB
# 102           Evadidos      45 a 49 anos   Bacharelado        IFPB
# 104           Evadidos      45 a 49 anos  Licenciatura        IFPB
# 106           Evadidos      45 a 49 anos    Tecnologia        IFPB
# 108           Evadidos      50 a 54 anos   Bacharelado        IFPB
# 110           Evadidos      50 a 54 anos  Licenciatura        IFPB
# 112           Evadidos      50 a 54 anos    Tecnologia        IFPB
# 114           Evadidos      55 a 59 anos   Bacharelado        IFPB
# 116           Evadidos      55 a 59 anos  Licenciatura        IFPB
# 119           Evadidos      55 a 59 anos    Tecnologia        IFPB
# 121           Evadidos  Maior de 60 anos  Licenciatura        IFPB
# 123           Evadidos  Maior de 60 anos    Tecnologia        IFPB
# 126           Evadidos  Menor de 14 anos    Tecnologia        IFPB
#
#      quant_grupo
# 1              1
# 3             81
# 5             55
# 8            322
# 10           100
# 12            55
# 15           290
# 17            29
# 19            41
# 22           143
# 24             8
# 26            41
# 29            59
# 31             5
# 33            22
# 36            42
# 38             5
# 40            11
# 43            19
# 45             3
# 47             7
# 49            13
# 51             1
# 53             3
# 55            13
# 57             3
# 59             4
# 63            44
# 64            47
# 66           147
# 68           105
# 70           232
# 74           699
# 76            91
# 78           212
# 80           421
# 82            51
# 84           190
# 87           281
# 89            24
# 91           128
# 93           165
# 95             5
# 97            65
# 100           86
# 102            4
# 104           36
# 106           33
# 108            3
# 110           23
# 112           20
# 114            2
# 116            7
# 119            8
# 121            1
# 123            6
# 126            2

# %% [markdown]
# ## Agrupando

# %% [markdown]
# ### Agrupando os valores para apresentar no gráfico

# %%
df = original_df.groupby(['categoria_situacao',field]).sum('quant_grupo').reset_index()
df_qtd = original_df.groupby([field]).sum('quant_grupo').reset_index()
order = list(df_qtd.sort_values('quant_grupo', ascending=False)[field])

# %% [markdown]
# ### Ordenação personalizada

# %%
order = [
    'Menor de 14 anos',
    '15 a 19 anos',
    '20 a 24 anos',
    '25 a 29 anos',
    '30 a 34 anos',
    '35 a 39 anos',
    '40 a 44 anos',
    '45 a 49 anos',
    '50 a 54 anos',
    '55 a 59 anos',
    'Maior de 60 anos',
]

# %% [markdown]
# ### Ordenando dados

# %%
sort_keys = {v:k for k,v in enumerate(order)}
func_sort = lambda e: sort_keys[e]
df_cat = df.pivot_table('quant_grupo',[field],'categoria_situacao').sort_values(by=field, key=lambda col: col.map(func_sort))
df_qtd = df_qtd.pivot_table('quant_grupo',[field]).sort_values(by=field, key=lambda col: col.map(func_sort))

# %% [markdown]
# ### Apresentando o gráfico

# %%
df_qtd.plot(kind ='bar', figsize=(20, 8), width = 0.7)
# Out:
# <AxesSubplot:xlabel='faixa_etaria'>

# %%
df_cat.plot(kind ='bar', figsize=(20, 8), width = 0.7)
# Out:
# <AxesSubplot:xlabel='faixa_etaria'>

# %% [markdown]
# ## Total de Alunos

# %%
categories = list(df['categoria_situacao'].unique())
total = df['quant_grupo'].sum()
df_res = df_cat 
df_res['total'] = df_res[categories].sum(axis=1)
for category in categories:
    df_res[category + '_%'] = df_res[category] / df_res['total']
df_res['total_%'] = df_res['total'] / total
df_res
# Out:
# categoria_situacao  Concluintes  Evadidos   total  Concluintes_%  Evadidos_%  \
# faixa_etaria
# Menor de 14 anos            NaN       2.0     2.0            NaN    1.000000
# 15 a 19 anos                1.0     238.0   239.0       0.004184    0.995816
# 20 a 24 anos              458.0    1036.0  1494.0       0.306560    0.693440
# 25 a 29 anos              445.0     724.0  1169.0       0.380667    0.619333
# 30 a 34 anos              213.0     522.0   735.0       0.289796    0.710204
# 35 a 39 anos              108.0     317.0   425.0       0.254118    0.745882
# 40 a 44 anos               69.0     156.0   225.0       0.306667    0.693333
# 45 a 49 anos               35.0      73.0   108.0       0.324074    0.675926
# 50 a 54 anos               23.0      46.0    69.0       0.333333    0.666667
# 55 a 59 anos               17.0      17.0    34.0       0.500000    0.500000
# Maior de 60 anos            7.0       7.0    14.0       0.500000    0.500000
#
# categoria_situacao   total_%
# faixa_etaria
# Menor de 14 anos    0.000443
# 15 a 19 anos        0.052946
# 20 a 24 anos        0.330970
# 25 a 29 anos        0.258972
# 30 a 34 anos        0.162827
# 35 a 39 anos        0.094152
# 40 a 44 anos        0.049845
# 45 a 49 anos        0.023926
# 50 a 54 anos        0.015286
# 55 a 59 anos        0.007532
# Maior de 60 anos    0.003101

# %%
print("Total de alunos: {:,}".format(df['quant_grupo'].sum()).replace(',','.'))
# Out:
# Total de alunos: 4.514

# %% [markdown]
# # Porcentagem de Conclusão

# %%
df_drp = df_res['Concluintes_%'] * 100

df_drp.plot(kind ='bar', figsize=(20, 8), width = 0.7)
# Out:
# <AxesSubplot:xlabel='faixa_etaria'>
